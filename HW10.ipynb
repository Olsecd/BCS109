# %%
# load pandas and numpy libraries
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import missingno as msno
import seaborn as sns

df = pd.read_csv("https://raw.githubusercontent.com/Olsecd/BCS109/master/cereal.csv")
df.head()
# Out:
#                         name mfr type  calories  ...  shelf  weight  cups     rating
# 0                  100% Bran   N    C        70  ...      3     1.0  0.33  68.402973
# 1          100% Natural Bran   Q    C       120  ...      3     1.0  1.00  33.983679
# 2                   All-Bran   K    C        70  ...      3     1.0  0.33  59.425505
# 3  All-Bran with Extra Fiber   K    C        50  ...      3     1.0  0.50  93.704912
# 4             Almond Delight   R    C       110  ...      3     1.0  0.75  34.384843
#
# [5 rows x 16 columns]

# %%
#check for nulls
df.isnull().sum()
# Out:
# name        0
# mfr         0
# type        0
# calories    0
# protein     0
# fat         0
# sodium      0
# fiber       0
# carbo       0
# sugars      0
# potass      0
# vitamins    0
# shelf       0
# weight      0
# cups        0
# rating      0
# dtype: int64

# %%
#List number of unique values
#We see this matches with the information that is given about the data
df.nunique()
# Out:
# name        77
# mfr          7
# type         2
# calories    11
# protein      6
# fat          5
# sodium      27
# fiber       13
# carbo       22
# sugars      17
# potass      36
# vitamins     3
# shelf        3
# weight       7
# cups        12
# rating      77
# dtype: int64

# %%
df.describe()
# Out:
#          calories    protein        fat  ...     weight       cups     rating
# count   77.000000  77.000000  77.000000  ...  77.000000  77.000000  77.000000
# mean   106.883117   2.545455   1.012987  ...   1.029610   0.821039  42.665705
# std     19.484119   1.094790   1.006473  ...   0.150477   0.232716  14.047289
# min     50.000000   1.000000   0.000000  ...   0.500000   0.250000  18.042851
# 25%    100.000000   2.000000   0.000000  ...   1.000000   0.670000  33.174094
# 50%    110.000000   3.000000   1.000000  ...   1.000000   0.750000  40.400208
# 75%    110.000000   3.000000   2.000000  ...   1.000000   1.000000  50.828392
# max    160.000000   6.000000   5.000000  ...   1.500000   1.500000  93.704912
#
# [8 rows x 13 columns]

# %%
#we now check the scale
sns.catplot(data=df , kind='box' , height=4, aspect=2)

# %%
sns.catplot(x='calories', data=df , kind='count',height = 3, aspect=1.1 )

# %%
#histograms
df.hist(figsize=(15, 10), bins=20, xlabelsize=10, ylabelsize=10)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fbfec8c7438>,
# ...
#       dtype=object)

# %%
df2 = df.drop(['name','mfr','type'], axis = 1)
df2.head()
# Out:
#    calories  protein  fat  sodium  ...  shelf  weight  cups     rating
# 0        70        4    1     130  ...      3     1.0  0.33  68.402973
# 1       120        3    5      15  ...      3     1.0  1.00  33.983679
# 2        70        4    1     260  ...      3     1.0  0.33  59.425505
# 3        50        4    0     140  ...      3     1.0  0.50  93.704912
# 4       110        2    2     200  ...      3     1.0  0.75  34.384843
#
# [5 rows x 13 columns]

# %%
df.plot()

# %%
df.plot.hist()

# %%
corr = df2.corr()
fig, ax = plt.subplots(figsize=(10,10)) 
sns.heatmap(data=corr, square=True , annot=True, cbar=True, ax = ax)

# %% [markdown]
# # 2. Define "Data Science" and explain the data science process
# Data science is obtaining insights and information or anything of value out of data. The data science process involves finding data and cleaning it up. After that you need to make sure you understand the data, once you do you can model the data and then interpret the data to see what information you can find from it.
#
# # 3. What is the difference between lists and tuples
# Lists are mutable and tuples are immutable. A mutable data type means that a python object of this type can be modified. This means that lists can be edited while tuples cannot.
#
# # 4. Explain what the following major libraries do:
# scikit learn: Features various classification, regression and clustering algorithms including support vector machines, random forests, gradient boosting, k-means and DBSCAN, and is designed to interoperate with the Python numerical and scientific libraries NumPy and SciPy.
#
# pandas: Features data manipulation and analysis. In particular, it offers data structures and operations for manipulating numerical tables and time series.
#
# tensorflow: Numerical library intended for use in Deep Learning and designed for use both in research and development and in production systems.
#
# numpy: Adds support for large, multi-dimensional arrays and matrices, along with a large collection of high-level mathematical functions to operate on these arrays.
#
# tkinter: The standard Python interface to the Tk GUI toolkit.
